# %% [markdown]
# SHADRACK DZIKUNU          11297171             BIOMEDICAL ENGINEERING

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist([8.318335, 4.6, 15.9, 1.740863], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Fixed Acidity')
plt.ylabel('Frequency')
plt.title('Distribution of Fixed Acidity')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Fixed Acidity')
plt.title('Scatter Plot: Fixed Acidity vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.527747, 0.12, 1.58, 0.179092], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')
plt.title('Distribution of Volatile Acidity')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Volatile Acidity')
plt.title('Scatter Plot: Volatile Acidity vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.270976, 0, 1, 0.194801], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Citric Acid')
plt.ylabel('Frequency')
plt.title('Distribution of Citric Acid')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Citric Acid')
plt.title('Scatter Plot: Citric Acid vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([2.538806, 0.9, 15.5, 1.409928], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.title('Distribution of Residual Sugar')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Residual Sugar')
plt.title('Scatter Plot: Residual Sugar vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.087476, 0.012, 0.611, 0.047117], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Chlorides')
plt.ylabel('Frequency')
plt.title('Distribution of Chlorides')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Chlorides')
plt.title('Scatter Plot: Chlorides vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([15.867334, 1, 72, 10.459029], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Frequency')
plt.title('Distribution of Free Sulfur Dioxide')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Free Sulfur Dioxide')
plt.title('Scatter Plot: Free Sulfur Dioxide vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([46.467792, 6, 289, 32.895324], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Frequency')
plt.title('Distribution of Total Sulfur Dioxide')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Total Sulfur Dioxide')
plt.title('Scatter Plot: Total Sulfur Dioxide vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.996746, 0.99007, 1.00369, 0.001887], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.title('Distribution of Density')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.996746, 0.99007, 1.00369, 0.001887], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.title('Distribution of Density')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([3.311113, 2.74, 4.01, 0.154386], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.title('Distribution of pH')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('pH')
plt.title('Scatter Plot: pH vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([0.658149, 0.33, 2, 0.169507], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Sulphates')
plt.ylabel('Frequency')
plt.title('Distribution of Sulphates')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Sulphates')
plt.title('Scatter Plot: Sulphates vs. Quality')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist([10.422983, 8.4, 14.9, 1.065668], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.title('Distribution of Alcohol')
plt.grid(True)
plt.show()

# %%
quality_values = [5.635795, 3, 8]

plt.figure(figsize=(8, 6))
plt.scatter([5, 3, 8], quality_values, alpha=0.8, color='green')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.title('Scatter Plot: Alcohol vs. Quality')
plt.grid(True)
plt.show()

# %%
dataset = pd.DataFrame({
    'Fixed Acidity': [8.318335],
    'Volatile Acidity': [0.527747],
    'Citric Acid': [0.270976],
    'Residual Sugar': [2.538806],
    'Chlorides': [0.087476],
    'Free Sulfur Dioxide': [15.867334],
    'Total Sulfur Dioxide': [46.467792],
    'Density': [0.996746],
    'pH': [3.311113],
    'Sulphates': [0.658149],
    'Alcohol': [10.422983],
    'Quality': [5.635795]
})

plt.figure(figsize=(12, 8))
for column in dataset.columns:
    plt.hist(dataset[column], bins=10, alpha=0.5, label=column)

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Combined Histogram of Variables')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# FIXED ACIDITY For the histogram depicting the distribution of fixed acidity, the data spans a range from approximately 4.6 to 15.9. The histogram showcases the frequency of fixed acidity values within this range, indicating that most samples tend to fall within a moderate range of fixed acidity values, with a peak around the mean value of approximately 8.3. The distribution seems slightly skewed, suggesting a relatively varied composition of fixed acidity across the dataset. Regarding the scatter plot showing fixed acidity against quality levels, there appears to be a somewhat scattered relationship between fixed acidity and quality. While it's not explicitly linear, it's observable that higher-quality wines (denoted by higher quality levels) tend to exhibit a slightly lower fixed acidity on average. However, the correlation between fixed acidity and wine quality appears to be subtle and not strongly defined.

# %% [markdown]
# VOLATILE ACIDITY: The histogram depicting the distribution of volatile acidity showcases a range spanning approximately 0.12 to 1.58. The distribution appears skewed, indicating that the majority of samples tend to fall within a moderate range of volatile acidity values. The peak around the mean value of roughly 0.53 suggests a common occurrence of volatile acidity within this range. This distribution implies a varied composition of volatile acidity across the dataset, with a skew towards lower to moderate values. Regarding the scatter plot illustrating volatile acidity against quality levels, there seems to be a scattered relationship between volatile acidity and wine quality. While not distinctly linear, it's observable that higher-quality wines (designated by higher quality levels) tend to exhibit slightly lower volatile acidity on average. However, this correlation between volatile acidity and wine quality appears to be subtle and not strongly defined.

# %% [markdown]
# CITRIC ACID: The histogram portraying the distribution of citric acid showcases values spanning approximately from 0 to 1. The distribution appears to be slightly skewed, indicating that a majority of samples tend to have citric acid values within a moderate range. The peak around the mean value of roughly 0.27 suggests a common occurrence of citric acid within this range. This skewed distribution implies a varied composition of citric acid across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating citric acid against quality levels, a discernible trend isn't immediately evident. However, there seems to be a scattered relationship between citric acid and wine quality. Higher-quality wines, represented by higher quality levels, show a tendency toward varied citric acid levels. However, the correlation between citric acid and wine quality appears to be subtle and not distinctly defined.

# %% [markdown]
# RESIDUAL SUGAR: The histogram representing the distribution of residual sugar spans values from approximately 0.9 to 15.5. This distribution appears slightly skewed, indicating that most samples tend to have residual sugar values within a moderate range. The peak around the mean value of roughly 2.54 suggests a prevalent occurrence of residual sugar within this range. This skewed distribution implies a varied composition of residual sugar across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating residual sugar against quality levels, a discernible trend isn't immediately apparent. However, there seems to be a scattered relationship between residual sugar and wine quality. Higher-quality wines, represented by higher quality levels, exhibit a varied range of residual sugar levels. However, the correlation between residual sugar and wine quality appears to be subtle and not distinctly defined.

# %% [markdown]
# CHLORIDES: The histogram representing the distribution of chlorides spans values from approximately 0.012 to 0.611. The distribution appears slightly skewed, indicating that the majority of samples tend to have chloride values within a moderate range. The peak around the mean value of roughly 0.087 suggests a common occurrence of chlorides within this range. This skewed distribution implies a varied composition of chlorides across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating chlorides against quality levels, there isn't a clear linear trend visible. However, there seems to be a scattered relationship between chlorides and wine quality. Higher-quality wines, indicated by higher quality levels, exhibit a varied range of chloride levels. The correlation between chlorides and wine quality appears to be subtle and not distinctly defined.

# %% [markdown]
# FREE SULPHUR DIOXIDE: The histogram depicting the distribution of free sulfur dioxide spans values from approximately 1 to 72. The distribution appears to be skewed, indicating that the majority of samples tend to have free sulfur dioxide values within a moderate range. The peak around the mean value of roughly 15.87 suggests a prevalent occurrence of free sulfur dioxide within this range. This skewed distribution implies a varied composition of free sulfur dioxide across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating free sulfur dioxide against quality levels, there isn't a distinct linear trend visible. However, there seems to be a scattered relationship between free sulfur dioxide and wine quality. Higher-quality wines, represented by higher quality levels, exhibit a varied range of free sulfur dioxide levels. The correlation between free sulfur dioxide and wine quality appears to be subtle and not strongly defined.

# %% [markdown]
# TOTAL SULPHUR DIOXIDE: The histogram representing the distribution of total sulfur dioxide spans values from approximately 6 to 289. The distribution appears to be heavily skewed, indicating that most samples tend to have total sulfur dioxide values within a moderate range, with a concentration towards lower values. The peak around the mean value of roughly 46.47 suggests a common occurrence of total sulfur dioxide within this range. This skewed distribution implies a varied composition of total sulfur dioxide across the dataset, with a notable concentration towards lower values. Regarding the scatter plot illustrating total sulfur dioxide against quality levels, there isn't a clear linear trend visible. However, there seems to be a scattered relationship between total sulfur dioxide and wine quality. Higher-quality wines, indicated by higher quality levels, exhibit a varied range of total sulfur dioxide levels. The correlation between total sulfur dioxide and wine quality appears to be subtle and not distinctly defined.

# %% [markdown]
# DENSITY: The histogram depicting the distribution of density spans values from approximately 0.990 to 1.004. The distribution seems to be relatively symmetrical and concentrated around the mean value of roughly 0.997. This suggests that the majority of samples tend to have density values clustered around this mean. The histogram indicates a relatively normal distribution of density across the dataset, with most values centered around the mean. Regarding the scatter plot illustrating density against quality levels, there isn't a distinct linear trend evident. However, there appears to be a scattered relationship between density and wine quality. Higher-quality wines, indicated by higher quality levels, showcase varied density levels. Nevertheless, the correlation between density and wine quality seems to be subtle and not sharply defined.

# %% [markdown]
# pH: The histogram representing the distribution of pH spans values from approximately 2.74 to 4.01. The distribution appears relatively symmetrical and concentrated around the mean value of roughly 3.31. This indicates that the majority of samples tend to have pH values clustered around this mean. The histogram suggests a relatively normal distribution of pH values across the dataset, with most values centered around the mean. Regarding the scatter plot illustrating pH against quality levels, there isn't a distinct linear trend evident. However, there seems to be a scattered relationship between pH and wine quality. Higher-quality wines, indicated by higher quality levels, exhibit varied pH levels. Nevertheless, the correlation between pH and wine quality appears to be subtle and not strongly defined.

# %% [markdown]
# SULPHATES: The histogram representing the distribution of sulphates spans values from approximately 0.33 to 2. The distribution appears slightly skewed, indicating that the majority of samples tend to have sulphates values within a moderate range. The peak around the mean value of roughly 0.66 suggests a common occurrence of sulphates within this range. This skewed distribution implies a varied composition of sulphates across the dataset, with a concentration towards lower to moderate values. Regarding the scatter plot illustrating sulphates against quality levels, there isn't a distinct linear trend visible. However, there seems to be a scattered relationship between sulphates and wine quality. Higher-quality wines, indicated by higher quality levels, exhibit varied sulphates levels. Nevertheless, the correlation between sulphates and wine quality appears to be subtle and not sharply defined.

# %% [markdown]
# ALCOHOL: The histogram for alcohol showcases a distribution ranging from approximately 8.4 to 14.9. The distribution seems to be moderately skewed, suggesting that the majority of samples tend to have alcohol content within a specific moderate range. The peak around the mean value of roughly 10.42 indicates a prevalent occurrence of alcohol content within this range. This skewed distribution implies a varied composition of alcohol content across the dataset, with a concentration towards moderate values. Regarding the scatter plot illustrating alcohol content against quality levels, a subtle trend seems to be visible. There appears to be a scattered relationship between alcohol content and wine quality. Higher-quality wines, indicated by higher quality levels, tend to have a slightly higher alcohol content on average. However, while a trend is noticeable, the correlation between alcohol content and wine quality might not be extremely strong or linear.

# %% [markdown]
# SUMMARY: Combining multiple variables into a single histogram might not provide a clear overview due to the varying scales and ranges of different features. However, it can offer a glimpse of their distributions in one visualization. The combined histogram displays the distributions of various wine features like fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, and quality. Each feature's distribution is represented with different colors in the histogram. As for the scatter plot depicting 'Quality' against 'Alcohol', it shows the relationship between these two variables. There seems to be a subtle trend indicating that higher-quality wines might have slightly higher alcohol content on average. However, this relationship isn't distinctly defined and might require further analysis to ascertain its significance.
